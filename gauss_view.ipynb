# %%
import os
import skimage
from skimage import io, color
import matplotlib.pyplot as plt
import webcolors
import requests
from pprint import pprint
import numpy as np
from skimage.transform import rescale, resize, downscale_local_mean, resize_local_mean
from scipy.linalg import lu

# %%
img = io.imread("f.jpeg")
print(img.shape) # geometry
print(img.size) # the number of pixels
plt.imshow(img)
# Out:
# (1496, 1000, 3)
# 4488000

# %%
p1, l1, u1 = lu(img[:,:,0])
p2, l2, u2 = lu(img[:,:,1])
p3, l3, u3 = lu(img[:,:,2])
rgb = np.dstack((u1,u2,u3))
rgb.shape
# Out:
# (1000, 1000, 3)

# %%
plt.imshow(rgb)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
